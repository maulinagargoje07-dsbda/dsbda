# %%
import pandas as pd

# %%
x=pd.DataFrame({"RollNo":[1,2,3],"Name":["Tejas","Gauri","Yash"]})

# %%
x
# Out:
#    RollNo   Name
# 0       1  Tejas
# 1       2  Gauri
# 2       3   Yash

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RollNo  3 non-null      int64
#  1   Name    3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
x.describe()
# Out:
#        RollNo
# count     3.0
# mean      2.0
# std       1.0
# min       1.0
# 25%       1.5
# 50%       2.0
# 75%       2.5
# max       3.0

# %%
x.isnull()
# Out:
#    RollNo   Name
# 0   False  False
# 1   False  False
# 2   False  False

# %%
x.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
x.head(2)
# Out:
#    RollNo   Name
# 0       1  Tejas
# 1       2  Gauri

# %%
x.tail(1)
# Out:
#    RollNo  Name
# 2       3  Yash

# %%
x.tail(2)
# Out:
#    RollNo   Name
# 1       2  Gauri
# 2       3   Yash

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
type(x.RollNo)
# Out:
# pandas.core.series.Series
